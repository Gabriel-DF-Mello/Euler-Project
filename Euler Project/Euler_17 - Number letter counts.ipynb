# %%
one_nine = [3,3,5,4,4,3,5,5,4]

ten_nineteen = [3,6,6,8,8,7,7,9,8,8]

twenty_ninety = [6,6,5,5,5,7,6,6]

twenty = 6
thirty = 6
forty = 5
fifty = 5
sixty = 5
seventy = 7
eighty = 6
ninety = 6

hundred = 7

aand = 3

thousand = 8

# %%
one_to_nine = 36
# Out:
# 36

# %%
ten_to_nineteen = 70

# %%
twenty_to_ninety_nine = 748
# Out:
# 748

# %%
current_n = 0
total = one_to_nine + ten_to_nineteen + twenty_to_ninety_nine
this_total = 0

print(total)

for i in range (100,1000):
    string = str(i)
    
    for l in range(1,10):
        if string[0] == str(l):
            current_n = current_n + one_nine[l-1] + hundred
            message = 'num'
        
    if string[1] == '1':
        current_n += aand
        for l in range(0,10):
            if string[2] == str(l):
                current_n += ten_nineteen[l]
                message += ' and last num on tens'
    
    elif string[1] == '0':
        for l in range(1,10):
            if string[2] == str(l):
                current_n = current_n + aand + one_nine[l-1]
                message += ' and last num on ones'
                
    else:
        for l in range(2,10):
            if string[1] == str(l):
                current_n = current_n + aand + twenty_ninety[l-2]
                message += ' and mid num'
                for m in range(1,10):
                    if string[2] == str(m):
                        current_n += one_nine[m-1]
                        message += ' last num'

    this_total = this_total + current_n
    current_n = 0
    print (message)
    message = ''
print(this_total)
# Out:
# 854
# num
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on ones
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and last num on tens
# num and mid num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# num and mid num last num
# ...

# %%
total = one_to_nine + ten_to_nineteen + twenty_to_ninety_nine + this_total + (one_nine[0] + thousand)

# %%
total
# Out:
# 21124
