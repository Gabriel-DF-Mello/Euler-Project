# %%
num = 2 ** 1000

# %%
num
# Out:
# 

# %%
string = str(num)

# %%
v = []
for digit in string:
    n = int(digit)
    v.append(n)

# %%
v
# Out:
# [1,
#  0,
#  7,
#  1,
#  5,
#  0,
#  8,
#  6,
#  0,
#  7,
#  1,
#  8,
#  6,
#  2,
#  6,
#  7,
#  3,
#  2,
#  0,
#  9,
#  4,
#  8,
#  4,
#  2,
#  5,
#  0,
#  4,
#  9,
#  0,
#  6,
#  0,
#  0,
#  0,
#  1,
#  8,
#  1,
#  0,
#  5,
#  6,
#  1,
#  4,
#  0,
#  4,
#  8,
#  1,
#  1,
#  7,
#  0,
#  5,
#  5,
#  3,
#  3,
#  6,
#  0,
#  7,
#  4,
#  4,
#  3,
#  7,
#  5,
#  0,
#  3,
#  8,
#  8,
#  3,
#  7,
#  0,
#  3,
#  5,
#  1,
#  0,
#  5,
#  1,
#  1,
#  2,
#  4,
#  9,
#  3,
#  6,
#  1,
#  2,
#  2,
#  4,
#  9,
#  3,
#  1,
#  9,
#  8,
#  3,
#  7,
#  8,
#  8,
#  1,
#  5,
#  6,
#  9,
#  5,
#  8,
#  5,
#  8,
#  1,
#  2,
#  7,
#  5,
#  9,
#  4,
#  6,
#  7,
#  2,
#  9,
#  1,
#  7,
#  5,
#  5,
#  3,
#  1,
#  4,
#  6,
#  8,
#  2,
#  5,
#  1,
#  8,
#  7,
#  1,
#  4,
#  5,
#  2,
#  8,
#  5,
#  6,
#  9,
#  2,
#  3,
#  1,
#  4,
#  0,
#  4,
#  3,
#  5,
#  9,
#  8,
#  4,
#  5,
#  7,
#  7,
#  5,
#  7,
#  4,
#  6,
#  9,
#  8,
#  5,
#  7,
#  4,
#  8,
#  0,
#  3,
#  9,
#  3,
#  4,
#  5,
#  6,
#  7,
#  7,
#  7,
# ...

# %%
sum_of_digits = 0

for digit in v:
    sum_of_digits += digit

# %%
sum_of_digits
# Out:
# 1366
